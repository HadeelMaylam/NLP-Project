# %%
import pandas as pd

# %%
import string

# %%
df = pd.read_csv('data/series_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160884 entries, 0 to 160883
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   name         160858 non-null  object
#  1   slug         160840 non-null  object
#  2   image        114776 non-null  object
#  3   firstAired   140874 non-null  object
#  4   lastAired    140874 non-null  object
#  5   lastUpdated  160884 non-null  object
#  6   overview     143947 non-null  object
#  7   year         140874 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 9.8+ MB

# %%
df.head()
# Out:
#                                    name                                  slug  \
# 0  The Fall and Rise of Reginald Perrin  the-fall-and-rise-of-reginald-perrin
# 1          The New Adventures of Batman          the-new-adventures-of-batman
# 2           Legends of the Super-Heroes           legends-of-the-super-heroes
# 3                Tarzan and the Super 7                tarzan-and-the-super-7
# 4                       Larry King Live                       larry-king-live
#
#                           image  firstAired   lastAired          lastUpdated  \
# 0  /banners/posters/70908-1.jpg  1976-09-08  1979-01-24  2024-11-13 03:45:22
# 1  /banners/posters/70909-5.jpg  1977-02-10  1977-05-26  2024-10-23 05:32:01
# 2  /banners/posters/70910-2.jpg  1979-01-18  1979-01-25  2024-10-03 14:00:47
# 3  /banners/posters/70911-1.jpg  1978-01-13  1979-04-21  2023-03-14 02:54:52
# 4  /banners/posters/70912-1.jpg  1985-06-03  2023-10-16  2024-10-13 17:02:20
#
#                                             overview    year
# 0  Disillusioned after a long career at Sunshine ...  1976.0
# 1  The New Adventures of Batman is an animated se...  1977.0
# 2  Heroes and villains of DC Comics square off in...  1979.0
# 3  Tarzan and the Super 7, is a Saturday morning ...  1978.0
# 4  Larry King Live was an American talk show host...  1985.0

# %%
# remove null overview and name
df = df[df['name'].notnull()]
df = df[df['overview'].notnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143945 entries, 0 to 160883
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   name         143945 non-null  object
#  1   slug         143921 non-null  object
#  2   image        105192 non-null  object
#  3   firstAired   128163 non-null  object
#  4   lastAired    128163 non-null  object
#  5   lastUpdated  143945 non-null  object
#  6   overview     143945 non-null  object
#  7   year         128163 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 9.9+ MB

# %%
# remove year before 2020
df = df[df['year'] >= 2020]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72743 entries, 364 to 160883
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         72743 non-null  object
#  1   slug         72742 non-null  object
#  2   image        56931 non-null  object
#  3   firstAired   72743 non-null  object
#  4   lastAired    72743 non-null  object
#  5   lastUpdated  72743 non-null  object
#  6   overview     72743 non-null  object
#  7   year         72743 non-null  float64
# dtypes: float64(1), object(7)
# memory usage: 5.0+ MB

# %%
df['text'] = df['overview']

# %%
# To lowercase
df['text'] = df['text'].apply(lambda s: s.lower())
df.head()
# Out:
#                     name               slug  \
# 364   Your Face or Mine?  your-face-or-mine
# 1774    A Current Affair   a-current-affair
# 3435             The Den            the-den
# 5332        SportsCenter       sportscenter
# 6095    The World's Best    the-worlds-best
#
#                                                 image  firstAired   lastAired  \
# 364                      /banners/posters/71382-1.jpg  2017-05-17  2019-12-11
# 1774  /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30  2024-01-02
# 3435                     /banners/posters/75580-1.jpg  2020-11-08  2020-12-20
# 5332                     /banners/posters/77967-1.jpg  2017-06-20  2017-06-20
# 6095               /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03  2019-03-13
#
#               lastUpdated                                           overview  \
# 364   2023-11-17 02:28:49  Jimmy Carr and Katherine Ryan host a new "Tind...
# 1774  2024-08-14 02:16:39  A Current Affair is an Australian current affa...
# 3435  2024-07-15 20:16:22  The Den was the long-running children's televi...
# 5332  2023-08-11 14:56:36  SportsCenter debuted on September 7, 1979 to l...
# 6095  2020-08-12 19:47:40  A first-of-its-kind global talent competition ...
#
#         year                                               text
# 364   2017.0  jimmy carr and katherine ryan host a new "tind...
# 1774  2023.0  a current affair is an australian current affa...
# 3435  2020.0  the den was the long-running children's televi...
# 5332  2017.0  sportscenter debuted on september 7, 1979 to l...
# 6095  2019.0  a first-of-its-kind global talent competition ...

# %%
# Remove puncutation
df['text'] = df['text'].apply(lambda s: s.translate(str.maketrans('', '', string.punctuation)))
df.head()
# Out:
#                     name               slug  \
# 364   Your Face or Mine?  your-face-or-mine
# 1774    A Current Affair   a-current-affair
# 3435             The Den            the-den
# 5332        SportsCenter       sportscenter
# 6095    The World's Best    the-worlds-best
#
#                                                 image  firstAired   lastAired  \
# 364                      /banners/posters/71382-1.jpg  2017-05-17  2019-12-11
# 1774  /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30  2024-01-02
# 3435                     /banners/posters/75580-1.jpg  2020-11-08  2020-12-20
# 5332                     /banners/posters/77967-1.jpg  2017-06-20  2017-06-20
# 6095               /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03  2019-03-13
#
#               lastUpdated                                           overview  \
# 364   2023-11-17 02:28:49  Jimmy Carr and Katherine Ryan host a new "Tind...
# 1774  2024-08-14 02:16:39  A Current Affair is an Australian current affa...
# 3435  2024-07-15 20:16:22  The Den was the long-running children's televi...
# 5332  2023-08-11 14:56:36  SportsCenter debuted on September 7, 1979 to l...
# 6095  2020-08-12 19:47:40  A first-of-its-kind global talent competition ...
#
#         year                                               text
# 364   2017.0  jimmy carr and katherine ryan host a new tinde...
# 1774  2023.0  a current affair is an australian current affa...
# 3435  2020.0  the den was the longrunning childrens televisi...
# 5332  2017.0  sportscenter debuted on september 7 1979 to la...
# 6095  2019.0  a firstofitskind global talent competition tha...

# %%
import re

# %%
df['text'] = df['text'].apply(lambda s: re.sub(r'[^a-zA-Z\s]', '', s))
df.head()
# Out:
#                     name               slug  \
# 364   Your Face or Mine?  your-face-or-mine
# 1774    A Current Affair   a-current-affair
# 3435             The Den            the-den
# 5332        SportsCenter       sportscenter
# 6095    The World's Best    the-worlds-best
#
#                                                 image  firstAired   lastAired  \
# 364                      /banners/posters/71382-1.jpg  2017-05-17  2019-12-11
# 1774  /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30  2024-01-02
# 3435                     /banners/posters/75580-1.jpg  2020-11-08  2020-12-20
# 5332                     /banners/posters/77967-1.jpg  2017-06-20  2017-06-20
# 6095               /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03  2019-03-13
#
#               lastUpdated                                           overview  \
# 364   2023-11-17 02:28:49  Jimmy Carr and Katherine Ryan host a new "Tind...
# 1774  2024-08-14 02:16:39  A Current Affair is an Australian current affa...
# 3435  2024-07-15 20:16:22  The Den was the long-running children's televi...
# 5332  2023-08-11 14:56:36  SportsCenter debuted on September 7, 1979 to l...
# 6095  2020-08-12 19:47:40  A first-of-its-kind global talent competition ...
#
#         year                                               text
# 364   2017.0  jimmy carr and katherine ryan host a new tinde...
# 1774  2023.0  a current affair is an australian current affa...
# 3435  2020.0  the den was the longrunning childrens televisi...
# 5332  2017.0  sportscenter debuted on september   to launch ...
# 6095  2019.0  a firstofitskind global talent competition tha...

# %%
# Remove Repetitive
df['text'] = df['text'].apply(lambda s: re.sub(r'\b\w*(\w)\1{2,}\w*\b', '', s))
df.head()
# Out:
#                     name               slug  \
# 364   Your Face or Mine?  your-face-or-mine
# 1774    A Current Affair   a-current-affair
# 3435             The Den            the-den
# 5332        SportsCenter       sportscenter
# 6095    The World's Best    the-worlds-best
#
#                                                 image  firstAired   lastAired  \
# 364                      /banners/posters/71382-1.jpg  2017-05-17  2019-12-11
# 1774  /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30  2024-01-02
# 3435                     /banners/posters/75580-1.jpg  2020-11-08  2020-12-20
# 5332                     /banners/posters/77967-1.jpg  2017-06-20  2017-06-20
# 6095               /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03  2019-03-13
#
#               lastUpdated                                           overview  \
# 364   2023-11-17 02:28:49  Jimmy Carr and Katherine Ryan host a new "Tind...
# 1774  2024-08-14 02:16:39  A Current Affair is an Australian current affa...
# 3435  2024-07-15 20:16:22  The Den was the long-running children's televi...
# 5332  2023-08-11 14:56:36  SportsCenter debuted on September 7, 1979 to l...
# 6095  2020-08-12 19:47:40  A first-of-its-kind global talent competition ...
#
#         year                                               text
# 364   2017.0  jimmy carr and katherine ryan host a new tinde...
# 1774  2023.0  a current affair is an australian current affa...
# 3435  2020.0  the den was the longrunning childrens televisi...
# 5332  2017.0  sportscenter debuted on september   to launch ...
# 6095  2019.0  a firstofitskind global talent competition tha...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\samad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Remove stopwords
df['text'] = df['text'].apply(lambda s: ' '.join(word for word in s.split() if word.lower() not in stop_words))
df.head()
# Out:
#                     name               slug  \
# 364   Your Face or Mine?  your-face-or-mine
# 1774    A Current Affair   a-current-affair
# 3435             The Den            the-den
# 5332        SportsCenter       sportscenter
# 6095    The World's Best    the-worlds-best
#
#                                                 image  firstAired   lastAired  \
# 364                      /banners/posters/71382-1.jpg  2017-05-17  2019-12-11
# 1774  /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30  2024-01-02
# 3435                     /banners/posters/75580-1.jpg  2020-11-08  2020-12-20
# 5332                     /banners/posters/77967-1.jpg  2017-06-20  2017-06-20
# 6095               /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03  2019-03-13
#
#               lastUpdated                                           overview  \
# 364   2023-11-17 02:28:49  Jimmy Carr and Katherine Ryan host a new "Tind...
# 1774  2024-08-14 02:16:39  A Current Affair is an Australian current affa...
# 3435  2024-07-15 20:16:22  The Den was the long-running children's televi...
# 5332  2023-08-11 14:56:36  SportsCenter debuted on September 7, 1979 to l...
# 6095  2020-08-12 19:47:40  A first-of-its-kind global talent competition ...
#
#         year                                               text
# 364   2017.0  jimmy carr katherine ryan host new tinderinspi...
# 1774  2023.0  current affair australian current affairs prog...
# 3435  2020.0  den longrunning childrens television strand ir...
# 5332  2017.0  sportscenter debuted september launch espn sho...
# 6095  2019.0  firstofitskind global talent competition featu...

# %%
# import spacy

# # Load spaCy language model
# nlp = spacy.load("en_core_web_sm")

# # Lemmatization function
# def lemmatize_text_spacy(text):
#     doc = nlp(text)  # Process the text
#     return ' '.join([token.lemma_ for token in doc])  # Extract lemmatized words

# # Apply lemmatization
# df['text'] = df['text'].apply(lemmatize_text_spacy)
# df.info()

# %%
# Remove single characters words
df['text'] = df['text'].apply(lambda s: re.sub(r'\b\w\b', '', s).strip())

# Remove single word rows
df = df[df['text'].str.split().apply(len) > 1]
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#                                         name  \
# 0                         Your Face or Mine?
# 1                           A Current Affair
# 2                                    The Den
# 3                               SportsCenter
# 4                           The World's Best
# ...                                      ...
# 58515                 A Murder in the Family
# 58516  Woodworking Tips, Tricks, and Secrets
# 58517         Trailer Park Boys: Jail Shorts
# 58518     Vores Jord - Kurs Mod Nye Eventyr
# 58519        The Last Party: Death On Tresco
#
#                                       slug  \
# 0                        your-face-or-mine
# 1                         a-current-affair
# 2                                  the-den
# 3                             sportscenter
# 4                          the-worlds-best
# ...                                    ...
# 58515        a-murder-in-the-family-458298
# 58516  woodworking-tips-tricks-and-secrets
# 58517        trailer-park-boys-jail-shorts
# 58518      vores-jord-kurs-mod-nye-eventyr
# 58519       the-last-party-death-on-tresco
#
#                                                    image  firstAired  \
# 0                           /banners/posters/71382-1.jpg  2017-05-17
# 1        /banners/series/73296/posters/5e8816a06c3a1.jpg  2023-08-30
# 2                           /banners/posters/75580-1.jpg  2020-11-08
# 3                           /banners/posters/77967-1.jpg  2017-06-20
# 4                     /banners/posters/5cc5ab72a8ad8.jpg  2019-02-03
# ...                                                  ...         ...
# 58515  /banners/v4/series/458298/posters/6770a941bddf...  2023-01-05
# 58516  /banners/v4/series/458304/posters/6770d1e4d33f...  2017-01-01
# 58517                                                NaN  2021-03-11
# 58518                                                NaN  2024-12-29
# 58519  /banners/v4/series/458307/posters/6770ed136955...  2024-12-28
#
#         lastAired          lastUpdated  \
# 0      2019-12-11  2023-11-17 02:28:49
# 1      2024-01-02  2024-08-14 02:16:39
# 2      2020-12-20  2024-07-15 20:16:22
# 3      2017-06-20  2023-08-11 14:56:36
# 4      2019-03-13  2020-08-12 19:47:40
# ...           ...                  ...
# 58515  2023-01-05  2024-12-29 01:43:31
# 58516  2017-01-01  2024-12-29 05:07:27
# 58517  2021-04-01  2024-12-29 04:42:42
# 58518  2024-12-29  2024-12-29 05:11:48
# 58519  2024-12-28  2024-12-29 06:32:52
#
#                                                 overview    year  \
# 0      Jimmy Carr and Katherine Ryan host a new "Tind...  2017.0
# 1      A Current Affair is an Australian current affa...  2023.0
# 2      The Den was the long-running children's televi...  2020.0
# 3      SportsCenter debuted on September 7, 1979 to l...  2017.0
# 4      A first-of-its-kind global talent competition ...  2019.0
# ...                                                  ...     ...
# 58515  Explore three shocking British murders in this...  2023.0
# 58516  Totaling over 11 total hours of content, these...  2017.0
# 58517  You thought the Jail series was over did ya? N...  2021.0
# 58518  Kom med på nye eventyr, når Mikkel, Marian, Al...  2024.0
# 58519  23-year-old Josh Clayton mysteriously disappea...  2024.0
#
#                                                     text
# 0      jimmy carr katherine ryan host new tinderinspi...
# 1      current affair australian current affairs prog...
# 2      den longrunning childrens television strand ir...
# 3      sportscenter debuted september launch espn sho...
# 4      firstofitskind global talent competition featu...
# ...                                                  ...
# 58515  explore three shocking british murders hauntin...
# 58516  totaling total hours content lectures goto res...
# 58517  thought jail series ya siree bob boys still ja...
# 58518  kom med  nye eventyr nr mikkel marian alfred o...
# 58519  yearold josh clayton mysteriously disappeared ...
#
# [58520 rows x 9 columns]

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()
tfidf = TfidfVectorizer(max_features=10000)
result = tfidf.fit_transform(df['text'])

# %%
tfidf_df = pd.DataFrame(result.toarray(), columns=tfidf.get_feature_names_out())
tfidf_df.info()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 tfidf_df = pd.DataFrame(result.toarray(), columns=tfidf.get_feature_names_out())
#       2 tfidf_df.info()
#
# File c:\Users\samad\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_compressed.py:1181, in _cs_matrix.toarray(self, order, out)
#    1179 if out is None and order is None:
#    1180     order = self._swap('cf')[0]
# -> 1181 out = self._process_toarray_args(order, out)
#    1182 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1183     raise ValueError('Output array must be C or F contiguous')
#
# File c:\Users\samad\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\sparse\_base.py:1301, in _spbase._process_toarray_args(self, order, out)
#    1299     return out
#    1300 else:
# -> 1301     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 105. GiB for an array with shape (58520, 240431) and data type float64

# %%
df.to_csv('data/processed_series_data.csv')

# %%
tfidf_df.to_csv('data/tfidf_only_10000.csv')
pd.concat([tfidf_df, df[['name', 'slug']].reset_index(drop=True)], axis=1).to_csv('data/tfidf_serieses.csv')
